# %%
import pandas as pd
cs=pd.read_csv(r"C:\Users\Dell\3D Objects\ML\BlackFriday.csv")
cs
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
cs.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.style.use('seaborn')
plt.figure(figsize=(5,5))
sn.distplot(cs['Purchase'],bins=5,kde=True)
plt.title("Distribution of purchase amout")
plt.xlabel('Purchase amount')
plt.ylabel('Number of people')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\269110855.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\269110855.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(cs['Purchase'],bins=5,kde=True)

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,5))
plt.subplot(2,2,1)
plt.title("Buying according to Gender")
sn.barplot(data=cs,x='Gender',y='Purchase',width=0.3)
plt.subplot(2,2,2)
plt.title("According to Gender, Number of People are buying products")
sn.countplot(data=cs,x='Gender',width=0.3)
plt.xlabel("Gender")
plt.ylabel("number of purchase")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\2328919070.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,5))
plt.subplot(2,2,1)
plt.title("Buying according to Marital Status",fontsize=10)
sn.barplot(data=cs,x='Marital_Status',y='Purchase',width=0.3)
plt.subplot(2,2,2)
sn.countplot(data=cs,x='Marital_Status',width=0.3)
plt.title("According to Marital Status, Number of People are buying products",fontsize=10)
plt.ylabel("number of purchase")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\1543444251.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
plt.figure(figsize=(4,4))
color = ["Green", "Blue", "Red", "Yellow", "Pink", "Grey","Orange"]
labels =[]
lst=[]
values=dict(cs['Age'].value_counts())
for i in values:
 labels.append(i)
 lst.append(values[i])
plt.pie(lst,labels=labels,colors=color,autopct='%0.5f%%',startangle=20)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\3966748836.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,5))
sn.lineplot(data=cs,x="Product_Category_1",y="Purchase")
plt.title("Purchase value according to Product Category 1")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\242716801.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,5))
sn.lineplot(data=cs,x="Product_Category_2",y="Purchase")
plt.title("Purchase Value according to Product Category 2")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\887274717.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,5))
sn.boxplot(data=cs,x="Purchase",width=0.5)
plt.title("Puchase Value Statistics")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\3402438904.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use("seaborn")
sn.pairplot(data=cs)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\889417149.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.style.use("seaborn")
sn.heatmap(cs.corr(numeric_only=True),annot=True)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\2914545265.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.style.use('seaborn')
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title("Buying according to product category1")
sn.countplot(data=cs,x='Product_Category_1')
plt.ylabel("number of purchase")
plt.subplot(2,2,2)
sn.countplot(data=cs,x='Product_Category_2')
plt.ylabel("number of purchase")
plt.title("Buying according to product category2")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\4009966218.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
for i in range(2,11):
    print(cs[cs.columns[i]].value_counts())
# Out:
# Gender
# M    405380
# F    132197
# Name: count, dtype: int64
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64
# Occupation
# 4     70862
# 0     68120
# 7     57806
# 1     45971
# 17    39090
# 20    32910
# 12    30423
# 14    26712
# 2     25845
# 16    24790
# 6     19822
# 3     17366
# 10    12623
# 5     11985
# 15    11812
# 11    11338
# 19     8352
# 13     7548
# 18     6525
# 9      6153
# 8      1524
# Name: count, dtype: int64
# City_Category
# B    226493
# C    166446
# A    144638
# Name: count, dtype: int64
# Stay_In_Current_City_Years
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# 0      72725
# Name: count, dtype: int64
# Marital_Status
# 0    317817
# 1    219760
# Name: count, dtype: int64
# Product_Category_1
# 5     148592
# 1     138353
# 8     112132
# 11     23960
# 2      23499
# 6      20164
# 3      19849
# 4      11567
# ...

# %%
cs.Gender=cs.Gender.replace({'M':0,'F':1})

# %%
cs.Age=cs.Age.replace({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
cs.City_Category=cs.City_Category.replace({'A':1,'B':2,'C':3})

# %%
cs.Stay_In_Current_City_Years=cs.Stay_In_Current_City_Years.replace({'0':0,'1':1,'2':2,'3':3,'4+':4})

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  int64
#  3   Age                         537577 non-null  int64
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  int64
#  6   Stay_In_Current_City_Years  537577 non-null  int64
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(9), object(1)
# ...

# %%
cs.drop('User_ID',axis=1,inplace=True)

# %%
cs.drop('Product_ID',axis=1,inplace=True)

# %%
cs
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            1    1          10              1                           2
# 1            1    1          10              1                           2
# 2            1    1          10              1                           2
# 3            1    1          10              1                           2
# 4            0    7          16              3                           4
# ...        ...  ...         ...            ...                         ...
# 537572       0    4          16              3                           1
# 537573       0    4          16              3                           1
# 537574       0    4          16              3                           1
# 537575       0    4          16              3                           1
# 537576       0    4          16              3                           1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
cs.drop('Product_Category_3',axis=1,inplace=True)

# %%
cs['Product_Category_2'].fillna(8.0,inplace=True)

# %%
cs
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            1    1          10              1                           2
# 1            1    1          10              1                           2
# 2            1    1          10              1                           2
# 3            1    1          10              1                           2
# 4            0    7          16              3                           4
# ...        ...  ...         ...            ...                         ...
# 537572       0    4          16              3                           1
# 537573       0    4          16              3                           1
# 537574       0    4          16              3                           1
# 537575       0    4          16              3                           1
# 537576       0    4          16              3                           1
#
# ...

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      537577 non-null  int64
#  1   Age                         537577 non-null  int64
#  2   Occupation                  537577 non-null  int64
#  3   City_Category               537577 non-null  int64
#  4   Stay_In_Current_City_Years  537577 non-null  int64
#  5   Marital_Status              537577 non-null  int64
#  6   Product_Category_1          537577 non-null  int64
#  7   Product_Category_2          537577 non-null  float64
#  8   Purchase                    537577 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 36.9 MB

# %%
plt.style.use("seaborn")
sn.heatmap(cs.corr(numeric_only=True),annot=True)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\2914545265.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x=cs.drop("Purchase",axis=1)
y=cs["Purchase"]
s.fit_transform(x)
# Out:
# array([[ 1.75113795, -1.84443901,  0.29387746, ..., -0.83154501,
#         -0.6120319 , -0.2947123 ],
#        [ 1.75113795, -1.84443901,  0.29387746, ..., -0.83154501,
#         -1.14526606, -0.75885388],
#        [ 1.75113795, -1.84443901,  0.29387746, ..., -0.83154501,
#          1.78752181, -0.2947123 ],
#        ...,
#        [-0.57105724,  0.37354097,  1.21354261, ..., -0.83154501,
#          0.72105349,  1.32978324],
#        [-0.57105724,  0.37354097,  1.21354261, ..., -0.83154501,
#         -0.07879774, -0.2947123 ],
#        [-0.57105724,  0.37354097,  1.21354261, ..., -0.83154501,
#         -0.07879774, -0.2947123 ]])

# %%
feature_names=[i for i in x.columns]
feature_names
# Out:
# ['Gender',
#  'Age',
#  'Occupation',
#  'City_Category',
#  'Stay_In_Current_City_Years',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2']

# %%
from sklearn.feature_selection import SelectKBest,chi2
se=SelectKBest(k=5,score_func=chi2)
selected_feature=se.fit(x,y)
i=se.get_support()
print("Selected Feature:")
feature=[feature_names[j] for j in range(len(feature_names)) 
         if i[j]==True]
print(feature)
# Out:
# Selected Feature:
# ['Gender', 'Occupation', 'Stay_In_Current_City_Years', 'Product_Category_1', 'Product_Category_2']

# %%
x=x.drop(['Age','City_Category','Marital_Status'],axis=1)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,LassoCV,RidgeCV
from sklearn.tree import DecisionTreeRegressor,ExtraTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
m1=LinearRegression()
m2=Lasso(alpha=1.0)
m3=Ridge(alpha=1.0)
m4=LassoCV(cv=5)
m5=RidgeCV(cv=5)
m6=DecisionTreeRegressor()
m7=ExtraTreeRegressor()
m8=KNeighborsRegressor()
m9=RandomForestRegressor()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.03,random_state=0)

# %%
m1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m2.fit(x_train,y_train)
# Out:
# Lasso()

# %%
m3.fit(x_train,y_train)
# Out:
# Ridge()

# %%
m4.fit(x_train,y_train)
# Out:
# LassoCV(cv=5)

# %%
m5.fit(x_train,y_train)
# Out:
# RidgeCV(cv=5)

# %%
m6.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
m7.fit(x_train,y_train)
# Out:
# ExtraTreeRegressor()

# %%
m8.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
m9.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred1=m1.predict(x_test)
y_pred2=m2.predict(x_test)
y_pred3=m3.predict(x_test)
y_pred4=m4.predict(x_test)
y_pred5=m5.predict(x_test)
y_pred6=m6.predict(x_test)
y_pred7=m7.predict(x_test)
y_pred8=m8.predict(x_test)
y_pred9=m9.predict(x_test)

# %%
def mape(y1,y2):
    l1=list(y1)
    l2=list(y2)
    n=len(l1)
    sum1=0
    for i in range(n):
        error=np.abs(l1[i]-l2[i])/l1[i]
        sum1=sum1+error
    return (sum1/n)*100

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,mean_absolute_percentage_error
import numpy as np
mae1=mean_absolute_error(y_test,y_pred1)
print("Mean_Absolute Error Linear Regression",mae1)
mse1=mean_squared_error(y_test,y_pred1)
print("Mean Squared Error Linear Regression:",mse1)
rmse1=np.sqrt(mse1)
print("Root Mean Squared Error:",rmse1)
r2_m1=r2_score(y_test,y_pred1) 
print("R2 Score Linear Regression",r2_m1)
mape1=mape(y_test,y_pred1)
print("Mean Absolute Percentage_Error Linear Regression",mape1)
acc_score=100-mape1
print("Accuracy Score LR:",acc_score)
n=len(y_test)
k=5
adjusted_r2_m1=1-((1-r2_m1)*(n-1)/(n-k-1))
print("Adjusted r2 LR:",adjusted_r2_m1)
# Out:
# Mean_Absolute Error Linear Regression 3663.3586182279405
# Mean Squared Error Linear Regression: 22620346.72952209
# Root Mean Squared Error: 4756.085231524146
# R2 Score Linear Regression 0.09281333550552484
# Mean Absolute Percentage_Error Linear Regression 70.55335022602594
# Accuracy Score LR: 29.44664977397406
# Adjusted r2 LR: 0.09253198497069837

# %%
mae2=mean_absolute_error(y_test,y_pred2)
print("Mean_Absolute Error Lasso Regression",mae2)
mse2=mean_squared_error(y_test,y_pred2)
print("Mean Squared Error Lasso Regression:",mse2)
rmse2=np.sqrt(mse2)
print("Root Mean Squared Error Lasso Regression:",rmse1)
r2_m2=r2_score(y_test,y_pred2)
print("R2 Score Lasso Regression",r2_m2)
mape2=mape(y_test,y_pred2)
print("Mean Absolute Percentage_Error Lasso Regression",mape2)
acc_score2=100-mape2
print("Accuracy Score Lasso Regression:",acc_score2)
n=len(y_test)
k=5
adjusted_r2_m2=1-((1-r2_m2)*(n-1)/(n-k-1))
print("Adjusted r2 Lasso Regression:",adjusted_r2_m2)
# Out:
# Mean_Absolute Error Lasso Regression 3663.3387812106994
# Mean Squared Error Lasso Regression: 22620482.38806208
# Root Mean Squared Error Lasso Regression: 4756.085231524146
# R2 Score Lasso Regression 0.09280789493381869
# Mean Absolute Percentage_Error Lasso Regression 70.55571820832401
# Accuracy Score Lasso Regression: 29.44428179167599
# Adjusted r2 Lasso Regression: 0.09252654271167937

# %%
mae3=mean_absolute_error(y_test,y_pred3)
print("Mean_Absolute Error Ridge Regression",mae3)
mse3=mean_squared_error(y_test,y_pred3)
print("Mean Squared Error Ridge Regression:",mse3)
rmse3=np.sqrt(mse3)
print("Root Mean Squared Error Ridge Regression:",rmse3)
r2_m3=r2_score(y_test,y_pred3)
print("R2 Score Ridge Regression",r2_m3)
mape3=mape(y_test,y_pred3)
print("Mean Absolute Percentage_Error Ridge Regression",mape3)
acc_score3=100-mape3
print("Accuracy Score Ridge Regression:",acc_score3)
n=len(y_test)
k=5
adjusted_r2_m3=1-((1-r2_m3)*(n-1)/(n-k-1))
print("Adjusted r2 Ridge Regression:",adjusted_r2_m3)
# Out:
# Mean_Absolute Error Ridge Regression 3663.358574947194
# Mean Squared Error Ridge Regression: 22620346.61305859
# Root Mean Squared Error Ridge Regression: 4756.085219280516
# R2 Score Ridge Regression 0.09281334017628162
# Mean Absolute Percentage_Error Ridge Regression 70.55335110485434
# Accuracy Score Ridge Regression: 29.446648895145657
# Adjusted r2 Ridge Regression: 0.09253198964290366

# %%
mae4=mean_absolute_error(y_test,y_pred4)
print("Mean_Absolute Error LassoCV Regression",mae4)
mse4=mean_squared_error(y_test,y_pred4)
print("Mean Squared Error LassoCV Regression:",mse4)
rmse4=np.sqrt(mse4)
print("Root Mean Squared Error LassoCV Regression:",rmse1)
r2_m4=r2_score(y_test,y_pred4)
print("R2 Score LassoCV Regression",r2_m4)
mape4=mape(y_test,y_pred4)
print("Mean Absolute Percentage_Error LassoCV Regression",mape4)
acc_score4=100-mape4
print("Accuracy Score LassoCV Regression:",acc_score4)
n=len(y_test)
k=5
adjusted_r2_m4=1-((1-r2_m4)*(n-1)/(n-k-1))
print("Adjusted r2 LassoCV Regression:",adjusted_r2_m4)
# Out:
# Mean_Absolute Error LassoCV Regression 3663.285988628831
# Mean Squared Error LassoCV Regression: 22621536.712833956
# Root Mean Squared Error LassoCV Regression: 4756.085231524146
# R2 Score LassoCV Regression 0.09276561134795991
# Mean Absolute Percentage_Error LassoCV Regression 70.5678831108711
# Accuracy Score LassoCV Regression: 29.432116889128906
# Adjusted r2 LassoCV Regression: 0.0924842460121914

# %%
mae5=mean_absolute_error(y_test,y_pred5)
print("Mean_Absolute Error RidgeCV Regression",mae5)
mse5=mean_squared_error(y_test,y_pred5)
print("Mean Squared Error RidgeCV Regression:",mse5)
rmse5=np.sqrt(mse5)
print("Root Mean Squared Error RidgeCV:",rmse5)
r2_m5=r2_score(y_test,y_pred5)
print("R2 Score RidgeCV Regression",r2_m5)
mape5=mape(y_test,y_pred5)
print("Mean Absolute Percentage_Error RidgeCV Regression",mape2)
acc_score5=100-mape5
print("Accuracy Score RidgCV:",acc_score5)
n=len(y_test)
k=5
adjusted_r2_m5=1-((1-r2_m5)*(n-1)/(n-k-1))
print("Adjusted r2 RidgCV:",adjusted_r2_m5)
# Out:
# Mean_Absolute Error RidgeCV Regression 3663.358185477452
# Mean Squared Error RidgeCV Regression: 22620345.565513503
# Root Mean Squared Error RidgeCV: 4756.085109153693
# R2 Score RidgeCV Regression 0.09281338218796897
# Mean Absolute Percentage_Error RidgeCV Regression 70.55571820832401
# Accuracy Score RidgCV: 29.446640984968937
# Adjusted r2 RidgCV: 0.09253203166762036

# %%
mae6=mean_absolute_error(y_test,y_pred6)
print("Mean_Absolute Error DecisionTree Regression",mae6)
mse6=mean_squared_error(y_test,y_pred6)
print("Mean Squared Error DecisionTree Regression:",mse6)
rmse6=np.sqrt(mse6)
print("Root Mean Squared Error DecisionTree:",rmse6)
r2_m6=r2_score(y_test,y_pred6)
print("R2 Score DecisionTree Regression",r2_m6)
mape6=mape(y_test,y_pred6)
print("Mean Absolute Percentage_Error DecisionTree Regression",mape6)
acc_score6=100-mape6
print("Accuracy Score DecisionTree Regression:",acc_score6)
n=len(y_test)
k=5
adjusted_r2_m6=1-((1-r2_m6)*(n-1)/(n-k-1))
print("Adjusted r2 DecisionTree:",adjusted_r2_m6)
# Out:
# Mean_Absolute Error DecisionTree Regression 2234.9845194489626
# Mean Squared Error DecisionTree Regression: 9518484.29606074
# Root Mean Squared Error DecisionTree: 3085.2040930967173
# R2 Score DecisionTree Regression 0.6182621724221103
# Mean Absolute Percentage_Error DecisionTree Regression 33.05452296659105
# Accuracy Score DecisionTree Regression: 66.94547703340895
# Adjusted r2 DecisionTree: 0.618143782077371

# %%
mae7=mean_absolute_error(y_test,y_pred7)
print("Mean_Absolute Error ExtraTree Regression",mae7)
mse7=mean_squared_error(y_test,y_pred7)
print("Mean Squared Error ExtraTree Regression:",mse7)
rmse7=np.sqrt(mse7)
print("Root Mean Squared Error ExtraTree Regression:",rmse7)
r2_m7=r2_score(y_test,y_pred7)
print("R2 Score ExtraTree Regression",r2_m7)
mape7=mape(y_test,y_pred7)
print("Mean Absolute Percentage_Error ExtraTree Regression",mape7)
acc_score7=100-mape7
print("Accuracy Score ExtraTree Regression:",acc_score7)
n=len(y_test)
k=5
adjusted_r2_m7=1-((1-r2_m7)*(n-1)/(n-k-1))
print("Adjusted r2 ExtraTree regression:",adjusted_r2_m7)
# Out:
# Mean_Absolute Error ExtraTree Regression 2239.8879404135423
# Mean Squared Error ExtraTree Regression: 9582631.104545865
# Root Mean Squared Error ExtraTree Regression: 3095.5825145755466
# R2 Score ExtraTree Regression 0.615689571306689
# Mean Absolute Percentage_Error ExtraTree Regression 33.21235646672974
# Accuracy Score ExtraTree Regression: 66.78764353327026
# Adjusted r2 ExtraTree regression: 0.6155703831077393

# %%
mae8=mean_absolute_error(y_test,y_pred8)
print("Mean_Absolute Error KNN Regression",mae8)
mse8=mean_squared_error(y_test,y_pred8)
print("Mean Squared Error KNN Regression:",mse8)
rmse8=np.sqrt(mse8)
print("Root Mean Squared Error KNN:",rmse8)
r2_m8=r2_score(y_test,y_pred8)
print("R2 Score KNN Regression",r2_m8)
mape8=mape(y_test,y_pred8)
print("Mean Absolute Percentage_Error KNN Regression",mape8)
acc_score8=100-mape8
print("Accuracy Score KNN:",acc_score8)
n=len(y_test)
k=5
adjusted_r2_m8=1-((1-r2_m8)*(n-1)/(n-k-1))
print("Adjusted r2 KNN:",adjusted_r2_m8)
# Out:
# Mean_Absolute Error KNN Regression 2341.7580853174604
# Mean Squared Error KNN Regression: 10262056.350679563
# Root Mean Squared Error KNN: 3203.444451005755
# R2 Score KNN Regression 0.5884412921276195
# Mean Absolute Percentage_Error KNN Regression 35.66522882795537
# Accuracy Score KNN: 64.33477117204464
# Adjusted r2 KNN: 0.5883136532776405

# %%
mae9=mean_absolute_error(y_test,y_pred9)
print("Mean_Absolute Error RandomForest Regression",mae9)
mse9=mean_squared_error(y_test,y_pred9)
print("Mean Squared Error RandomForest Regression:",mse9)
rmse9=np.sqrt(mse9)
print("Root Mean Squared Error RandomForest:",rmse9)
r2_m9=r2_score(y_test,y_pred9)
print("R2 Score RandomForest Regression",r2_m9)
mape9=mape(y_test,y_pred9)
print("Mean Absolute Percentage_Error RandomForest Regression",mape9)
acc_score9=100-mape9
print("Accuracy Score RandomForest:",acc_score9)
n=len(y_test)
k=5
adjusted_r2_m9=1-((1-r2_m9)*(n-1)/(n-k-1))
print("Adjusted r2 RandomForest:",adjusted_r2_m9)
# Out:
# Mean_Absolute Error RandomForest Regression 2189.3944410860104
# Mean Squared Error RandomForest Regression: 8869331.685288316
# Root Mean Squared Error RandomForest: 2978.142321194257
# R2 Score RandomForest Regression 0.6442963706930825
# Mean Absolute Percentage_Error RandomForest Regression 32.67410867738916
# Accuracy Score RandomForest: 67.32589132261084
# Adjusted r2 RandomForest: 0.6441860544701241

# %%
dict1={"Accuracy score":(acc_score,acc_score2,acc_score3,acc_score4,acc_score5,acc_score6,acc_score7,acc_score8,acc_score9),
       "Mean Absolute Error":(mae1,mae2,mae3,mae4,mae5,mae6,mae7,mae8,mae9),
       "Mean Absolute Percentage Error":(mape1,mape2,mape3,mape4,mape5,mape6,mape7,mape8,mape9),
      "Mean Squared Error":(mse1,mse2,mse3,mse4,mse5,mse6,mse7,mse8,mse9),
      "Root Mean Squared Error":(rmse1,rmse2,rmse3,rmse4,rmse5,rmse6,rmse7,rmse8,rmse9),
      "R2 Score":(r2_m1,r2_m2,r2_m3,r2_m4,r2_m5,r2_m6,r2_m7,r2_m8,r2_m9),
      "Adjusted R2":(adjusted_r2_m1,adjusted_r2_m2,adjusted_r2_m3,adjusted_r2_m4,adjusted_r2_m5,adjusted_r2_m6,
                     adjusted_r2_m7,adjusted_r2_m8,adjusted_r2_m9)}
df=pd.DataFrame(dict1,index=("Linear Regression","Lasso","Ridge","LassoCV","RidgeCV","DecisionTreeRegression","ExtraTreeRegression","KNNRegression","RandomForestRegression"))
df
# Out:
#                         Accuracy score  Mean Absolute Error  \
# Linear Regression            29.446650          3663.358618
# Lasso                        29.444282          3663.338781
# Ridge                        29.446649          3663.358575
# LassoCV                      29.432117          3663.285989
# RidgeCV                      29.446641          3663.358185
# DecisionTreeRegression       66.945477          2234.984519
# ExtraTreeRegression          66.787644          2239.887940
# KNNRegression                64.334771          2341.758085
# RandomForestRegression       67.325891          2189.394441
#
#                         Mean Absolute Percentage Error  Mean Squared Error  \
# Linear Regression                            70.553350        2.262035e+07
# Lasso                                        70.555718        2.262048e+07
# Ridge                                        70.553351        2.262035e+07
# ...

# %%
plt.style.use('seaborn')
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
sn.distplot(y_pred1,bins=5,kde=True)
plt.title("Linear Rgression")
plt.subplot(3,3,2)
sn.distplot(y_pred2,bins=5,kde=True)
plt.title("Lasso Rgression")
plt.subplot(3,3,3)
sn.distplot(y_pred3,bins=5,kde=True)
plt.title("Ridge Rgression")
plt.subplot(3,3,4)
sn.distplot(y_pred4,bins=5,kde=True)
plt.title("LassoCV Rgression")
plt.subplot(3,3,5)
sn.distplot(y_pred5,bins=5,kde=True)
plt.title("RidgeCV Rgression")
plt.subplot(3,3,6)
sn.distplot(y_pred6,bins=5,kde=True)
plt.title("DecisionTree Rgression")
plt.subplot(3,3,7)
sn.distplot(y_pred7,bins=5,kde=True)
plt.title("ExtraTree Rgression")
plt.subplot(3,3,8)
sn.distplot(y_pred8,bins=5,kde=True)
plt.title("KNN Rgression")
plt.subplot(3,3,9)
sn.distplot(y_pred9,bins=5,kde=True)
plt.title("RandomForest Rgression")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\4219374621.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\4219374621.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(y_pred1,bins=5,kde=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10364\4219374621.py:7: UserWarning:
#
# ...
