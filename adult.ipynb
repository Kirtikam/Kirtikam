# %%
import pandas as pd
ad=pd.read_csv(r"C:\Users\Dell\3D Objects\ML\adult.csv")
ad
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
ad.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
ad.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt 
race=ad.race.unique() 
plt.figure(figsize=(5,5)) 
plt.pie(ad["race"].value_counts(),labels=race) 
plt.show()

# %%
import seaborn as sn 
sn.set(style="whitegrid") 
sn.scatterplot(x=ad["relationship"],y=ad["marital_status"],data=ad)
# Out:
# <Axes: xlabel='relationship', ylabel='marital_status'>

# %%
import seaborn as sn 
sn.set(style="whitegrid") 
sn.scatterplot(x=ad["workclass"],y=ad["occupation"],data=ad)
# Out:
# <Axes: xlabel='workclass', ylabel='occupation'>

# %%
plt.figure(figsize=(12,12)) 
sn.set(style="whitegrid") 
sn.barplot(x=ad["education"],y=ad["hours_per_week"],hue="salary",data=ad) 
plt.show()

# %%
sn.set(style="whitegrid") 
plt.figure(figsize=(20,20)) 
plt.subplot(3,2,1) 
sn.countplot(y="workclass",hue="salary",data=ad) 
plt.subplot(3,2,2) 
sn.countplot(y="education",hue="salary",data=ad) 
plt.subplot(3,2,3) 
sn.countplot(y="occupation",hue="salary",data=ad) 
plt.subplot(3,2,4) 
sn.countplot(y="sex",hue="salary",data=ad) 
plt.subplot(3,2,5) 
sn.countplot(y="relationship",hue="salary",data=ad) 
plt.subplot(3,2,6) 
sn.countplot(y="marital_status",hue="salary",data=ad)
# Out:
# <Axes: xlabel='count', ylabel='marital_status'>

# %%
from scipy.stats import norm      
import statistics      
mean = statistics.mean(ad["age"])  
sd = statistics.stdev(ad["age"])   
plt.plot(ad["age"], norm.pdf(ad["age"], mean, sd))  
plt.show()

# %%
sn.set(style="whitegrid") 
plt.figure(figsize=(20,20)) 
plt.subplot(3,2,1) 
sn.histplot(x="age",data=ad) 
plt.subplot(3,2,2) 
sn.histplot(x="fnlwgt",data=ad) 
plt.subplot(3,2,3) 
sn.histplot(x="capital_gain",data=ad) 
plt.subplot(3,2,4) 
sn.histplot(x="capital_loss",data=ad) 
plt.subplot(3,2,5) 
sn.histplot(x="hours_per_week",data=ad)
# Out:
# <Axes: xlabel='hours_per_week', ylabel='Count'>

# %%
sn.set(style="whitegrid") 
plt.figure(figsize=(20,20)) 
plt.subplot(2,3,1) 
sn.boxplot(x="age",data=ad) 
plt.subplot(2,3,2) 
sn.boxplot(x="fnlwgt",data=ad) 
plt.subplot(2,3,3) 
sn.boxplot(x="capital_gain",data=ad) 
plt.subplot(2,3,4) 
sn.boxplot(x="capital_loss",data=ad) 
plt.subplot(2,3,5) 
sn.boxplot(x="hours_per_week",data=ad)
# Out:
# <Axes: xlabel='hours_per_week'>

# %%
ad.drop('education',axis=1,inplace=True)

# %%
ad.rename(columns={"education_num":"education"},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in range(0,ad.shape[1]):
    if ad.dtypes[i]==object:
        ad[ad.columns[i]]=le.fit_transform(ad[ad.columns[i]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=ad.drop(['salary'],axis=1)
y=ad['salary']
x=sc.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
import warnings 
warnings.filterwarnings('ignore')
m1=LogisticRegression()
m2=DecisionTreeClassifier()
m3=KNeighborsClassifier()
m4=SVC()
m5=RandomForestClassifier()
print("model is created")
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
# Out:
# model is created

# %%
m1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
m2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
m3.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
m4.fit(x_train,y_train)
# Out:
# SVC()

# %%
m5.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int32
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int64
#  4   marital_status  32561 non-null  int32
#  5   occupation      32561 non-null  int32
#  6   relationship    32561 non-null  int32
#  7   race            32561 non-null  int32
#  8   sex             32561 non-null  int32
#  9   capital_gain    32561 non-null  int64
#  10  capital_loss    32561 non-null  int64
#  11  hours_per_week  32561 non-null  int64
#  12  native_country  32561 non-null  int32
#  13  salary          32561 non-null  int32
# dtypes: int32(8), int64(6)
# memory usage: 2.5 MB

# %%
ad
# Out:
#        age  workclass  fnlwgt  education  marital_status  occupation  \
# 0       39          7   77516         13               4           1
# 1       50          6   83311         13               2           4
# 2       38          4  215646          9               0           6
# 3       53          4  234721          7               2           6
# 4       28          4  338409         13               2          10
# ...    ...        ...     ...        ...             ...         ...
# 32556   27          4  257302         12               2          13
# 32557   40          4  154374          9               2           7
# 32558   58          4  151910          9               6           1
# 32559   22          4  201490          9               4           1
# 32560   52          5  287927          9               2           4
#
#        relationship  race  sex  capital_gain  capital_loss  hours_per_week  \
# ...

# %%
ad.skew()
# Out:
# age                0.558743
# workclass         -0.752024
# fnlwgt             1.446980
# education         -0.311676
# marital_status    -0.013508
# occupation         0.114583
# relationship       0.786818
# race              -2.435386
# sex               -0.719293
# capital_gain      11.953848
# capital_loss       4.594629
# hours_per_week     0.227643
# native_country    -3.658303
# salary             1.212430
# dtype: float64

# %%
print("LogisticRegreession Score:",m1.score(x_train,y_train))
print("DecisionTreeClassifier Score:",m2.score(x_train,y_train))
print("KneighbourClassifier Score:",m3.score(x_train,y_train))
print("SVC Score:",m4.score(x_train,y_train))
print("RandomForest score:",m5.score(x_train,y_train))
# Out:
# LogisticRegreession Score: 0.8246314496314496
# DecisionTreeClassifier Score: 1.0
# KneighbourClassifier Score: 0.8766233766233766
# SVC Score: 0.8556949806949807
# RandomForest score: 0.9998244998244998

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred1=m1.predict(x_test)
print("Confusion matrix of logistic regression\n",confusion_matrix(y_test,y_pred1))
y_pred2=m2.predict(x_test)
print("Confusion matrix of DeccisionTree Classifier\n",confusion_matrix(y_test,y_pred2))
y_pred3=m3.predict(x_test)
print("Confusion matrix of KneighbourClassifier\n",confusion_matrix(y_test,y_pred3))
y_pred4=m4.predict(x_test)
print("Confusion matrix of SVC\n",confusion_matrix(y_test,y_pred4))
y_pred5=m5.predict(x_test)
print("Confusion matrix of Randomforest\n",confusion_matrix(y_test,y_pred5))
# Out:
# Confusion matrix of logistic regression
#  [[7017  438]
#  [1267 1047]]
# Confusion matrix of DeccisionTree Classifier
#  [[6496  959]
#  [ 893 1421]]
# Confusion matrix of KneighbourClassifier
#  [[6772  683]
#  [ 970 1344]]
# Confusion matrix of SVC
#  [[7070  385]
#  [1056 1258]]
# Confusion matrix of Randomforest
#  [[6939  516]
#  [ 872 1442]]

# %%
print("classification report for logistic:",'\n',classification_report(y_test,y_pred1))
print("classification report for DecisionTree:",'\n',classification_report(y_test,y_pred2))
print("classification report for kneighbourclassifier:",'\n',classification_report(y_test,y_pred3))
print("classification report for SVC:",'\n',classification_report(y_test,y_pred4))
print("classification report for RandomForest:",'\n',classification_report(y_test,y_pred5))
# Out:
# classification report for logistic:
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      7455
#            1       0.71      0.45      0.55      2314
#
#     accuracy                           0.83      9769
#    macro avg       0.78      0.70      0.72      9769
# weighted avg       0.81      0.83      0.81      9769
#
# classification report for DecisionTree:
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      7455
#            1       0.60      0.61      0.61      2314
#
#     accuracy                           0.81      9769
#    macro avg       0.74      0.74      0.74      9769
# weighted avg       0.81      0.81      0.81      9769
#
# classification report for kneighbourclassifier:
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      7455
#            1       0.66      0.58      0.62      2314
#
# ...

# %%
from sklearn.metrics import roc_curve,auc,roc_auc_score
print("roc_auc_score logisticregression",roc_auc_score(y_test,y_pred1))
print("roc_auc_score DecisionTree",roc_auc_score(y_test,y_pred2))
print("roc_auc_score kneighbour",roc_auc_score(y_test,y_pred3))
print("roc_auc_score SVC",roc_auc_score(y_test,y_pred4))
print("roc_auc_score Randomforest",roc_auc_score(y_test,y_pred5))
# Out:
# roc_auc_score logisticregression 0.6968553759897327
# roc_auc_score DecisionTree 0.7427248306896985
# roc_auc_score kneighbour 0.7445980405625919
# roc_auc_score SVC 0.7460020856919102
# roc_auc_score Randomforest 0.7769740308749646

# %%
import matplotlib.pyplot as plt
plt.figure()
fpr1,tpr1,threshold=roc_curve(y_test,y_pred1)
roc_auc1=auc(fpr1,tpr1)
plt.plot(fpr1,tpr1,color="darkorange",lw=2,label=f"ROC curve LogisticRegression(area={roc_auc1:.2f})")
fpr2,tpr2,threshold=roc_curve(y_test,y_pred2)
roc_auc2=auc(fpr2,tpr2)
plt.plot(fpr2,tpr2,color="yellow",lw=2,label=f"ROC curve DecisionTreeClassifier(area={roc_auc2:.2f})")
fpr3,tpr3,threshold=roc_curve(y_test,y_pred3)
roc_auc3=auc(fpr3,tpr3)
plt.plot(fpr3,tpr3,color="red",lw=2,label=f"ROC curve KneighbourClassifier(area={roc_auc3:.2f})")
fpr4,tpr4,threshold=roc_curve(y_test,y_pred4)
roc_auc4=auc(fpr4,tpr4)
plt.plot(fpr4,tpr4,color="pink",lw=2,label=f"ROC curve SVC(area={roc_auc4:.2f})")
fpr5,tpr5,threshold=roc_curve(y_test,y_pred5)
roc_auc5=auc(fpr5,tpr5)
plt.plot(fpr5,tpr5,color="brown",lw=2,label=f"ROC curve RandomForest(area={roc_auc5:.2f})")
plt.plot([0,1],[0,1],color="navy",lw=2,linestyle="--")
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
